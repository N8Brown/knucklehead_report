# %%
import pandas as pd

# %%
# Import data
season1 = pd.read_csv("raw_pitch_data/wakefti1992.csv")

# %%
season1
# Out:
#     Rk  Gcar  Gtm    Date   Tm Unnamed: 5  Opp    Rslt  Inngs     Dec  ...  \
# 0    1     1  103  Jul�31  PIT        NaN  STL   W,3-2     CG  W(1-0)  ...
# 1    2     2  107   Aug�5  PIT        NaN  NYM   W,6-2   GS-8  W(2-0)  ...
# 2    3     3  112  Aug�10  PIT          @  NYM   W,4-2   GS-8     NaN  ...
# 3    4     4  117  Aug�16  PIT        NaN  ATL   W,4-2     CG  W(3-0)  ...
# 4    5     5  122  Aug�21  PIT          @  SFG   L,5-6   GS-6  L(3-1)  ...
# 5    6     6  127  Aug�26  PIT          @  LAD   W,2-0    SHO  W(4-1)  ...
# 6    7     7  132   Sep�2  PIT        NaN  SFG   W,3-2   GS-9  W(5-1)  ...
# 7    8     8  137   Sep�7  PIT        NaN  CHC   L,5-6   GS-3     NaN  ...
# 8    9     9  142  Sep�13  PIT          @  PHI   L,3-6   GS-7     NaN  ...
# 9   10    10  147  Sep�18  PIT        NaN  PHI   W,5-2  CG(6)  W(6-1)  ...
# 10  11    11  152  Sep�23  PIT          @  MON   L,1-5   GS-7     NaN  ...
# ...

# %%
s1_columns = season1.columns

# %%
s1_columns
# Out:
# Index(['Rk', 'Gcar', 'Gtm', 'Date', 'Tm', 'Unnamed: 5', 'Opp', 'Rslt', 'Inngs',
#        'Dec', 'DR', 'IP', 'H', 'R', 'ER', 'BB', 'SO', 'HR', 'HBP', 'ERA', 'BF',
#        'Pit', 'Str', 'StL', 'StS', 'GB', 'FB', 'LD', 'PU', 'Unk', 'GSc', 'IR',
#        'IS', 'SB', 'CS', 'PO', 'AB', '2B', '3B', 'IBB', 'GDP', 'SF', 'ROE',
#        'aLI', 'WPA', 'acLI', 'cWPA', 'RE24', 'Entered', 'Exited'],
#       dtype='object')

# %%
games = season1[["Date", "Unnamed: 5", "Opp"]]

# %%
games
# Out:
#       Date Unnamed: 5  Opp
# 0   Jul�31        NaN  STL
# 1    Aug�5        NaN  NYM
# 2   Aug�10          @  NYM
# 3   Aug�16        NaN  ATL
# 4   Aug�21          @  SFG
# 5   Aug�26          @  LAD
# 6    Sep�2        NaN  SFG
# 7    Sep�7        NaN  CHC
# 8   Sep�13          @  PHI
# 9   Sep�18        NaN  PHI
# 10  Sep�23          @  MON
# 11  Sep�28          @  CHC
# 12   Oct�4          @  NYM

# %%
games["Year"]= "1992"
# Out:
# /home/pi/projects/knucklehead_report/venv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
